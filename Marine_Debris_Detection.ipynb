# %% [markdown]
# **Project: Marine Debris Detection using Deep Learning**
# ---------------------------------------------------
#
# **Problem Statement:**
# Marine debris, including plastics, metals, and other waste materials, has become a major environmental concern.
# It pollutes oceans and coastal areas, harms marine life, and disrupts ecosystems. Manual methods of detecting
# and tracking debris are slow, inefficient, and cannot cover large areas effectively.
#
# **Goal:**
# To develop an AI-based system that automatically detects and classifies marine debris (like plastic bottles,
# cans, ropes, and nets) from images of coastal or water-surface environments. This system aims to support
# sustainability by enabling faster and more accurate monitoring of marine pollution, helping organizations
# and communities take timely cleanup actions.

# %% [markdown]
# **Importing Dataset**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="fRWalsKDKxBwQXfca469")
project = rf.workspace("marine-debris").project("marine-debris-i2ge3")
version = project.version(49)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import cv2
import matplotlib.pyplot as plt
import os

# dataset path
img_path = "/content/marine-debris-49/train/images"

img = cv2.imread(os.path.join(img_path, image_files[0]))
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis('off')
plt.title("Marine Debris Image")
plt.show()
